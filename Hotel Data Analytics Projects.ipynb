# %% [markdown]
# # Importing Libaries

# %%
import pandas as pd

# %% [markdown]
# # Importing Dataset

# %%
df_bookings = pd.read_csv("fact_bookings.csv")

# %% [markdown]
# #Let's Explore The Dataset

# %%
df_bookings #by running the name of the data set it will us the dataset top 5 & lower 5 rows of dataset
# Out:
#               booking_id  property_id booking_date check_in_date  \
# 0       May012216558RT11      16558.0     27-04-22      1/5/2022
# 1       May012216558RT12      16558.0     30-04-22      1/5/2022
# 2       May012216558RT13      16558.0     28-04-22      1/5/2022
# 3       May012216558RT14      16558.0     28-04-22      1/5/2022
# 4       May012216558RT15      16558.0     27-04-22      1/5/2022
# ...                  ...          ...          ...           ...
# 11487  May082217558RT231      17558.0     5/5/2022      8/5/2022
# 11488  May082217558RT232      17558.0     3/5/2022      8/5/2022
# 11489  May082217558RT233      17558.0     8/5/2022      8/5/2022
# 11490  May082217558RT234      17558.0     17-04-22      8/5/2022
# 11491       May082217558          NaN          NaN           NaN
#
#       checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0          2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.sample(5) #sample function gives us random rows from the data set
# Out:
#               booking_id  property_id booking_date check_in_date  \
# 10138  May072218560RT314      18560.0     5/5/2022      7/5/2022
# 2567    May022217562RT16      17562.0     28-04-22      2/5/2022
# 557    May012217559RT113      17559.0     1/5/2022      1/5/2022
# 4526   May032219560RT212      19560.0     29-04-22      3/5/2022
# 6247   May052216559RT313      16559.0     29-04-22      5/5/2022
#
#       checkout_date  no_guests room_category booking_platform  ratings_given  \
# 10138      9/5/2022        1.0           RT3           others            3.0
# 2567       3/5/2022        1.0           RT1           others            NaN
# 557        7/5/2022        3.0           RT1           others            4.0
# 4526       4/5/2022        1.0           RT2           others            4.0
# 6247       6/5/2022        3.0           RT3     makeyourtrip            2.0
#
#       booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings.head() #this function will allow us to get top 5 rows of dataset
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11      16558.0     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12      16558.0     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13      16558.0     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14      16558.0     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15      16558.0     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.tail() #this function will allow us to get bottam 5 rows of dataset
# Out:
#               booking_id  property_id booking_date check_in_date  \
# 11487  May082217558RT231      17558.0     5/5/2022      8/5/2022
# 11488  May082217558RT232      17558.0     3/5/2022      8/5/2022
# 11489  May082217558RT233      17558.0     8/5/2022      8/5/2022
# 11490  May082217558RT234      17558.0     17-04-22      8/5/2022
# 11491       May082217558          NaN          NaN           NaN
#
#       checkout_date  no_guests room_category booking_platform  ratings_given  \
# 11487     10/5/2022        2.0           RT2   direct offline            3.0
# 11488      9/5/2022        4.0           RT2           others            3.0
# 11489     10/5/2022        2.0           RT2   direct offline            NaN
# 11490      13-05-22        2.0           RT2         tripster            4.0
# 11491           NaN        NaN           NaN              NaN            NaN
#
#       booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape # shape function gives us the total no. of rows and column from data set
# Out:
# (11492, 12)

# %%
df_bookings.info()  #info function will give us information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11492 entries, 0 to 11491
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         11492 non-null  object
#  1   property_id        11491 non-null  float64
#  2   booking_date       11491 non-null  object
#  3   check_in_date      11491 non-null  object
#  4   checkout_date      11491 non-null  object
#  5   no_guests          11488 non-null  float64
#  6   room_category      11491 non-null  object
#  7   booking_platform   11491 non-null  object
#  8   ratings_given      4797 non-null   float64
#  9   booking_status     11491 non-null  object
#  10  revenue_generated  11491 non-null  float64
#  11  revenue_realized   11491 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 1.1+ MB

# %%
df_bookings.isnull().sum() # isnull fucntion check the null values from dataset (this function mainly used in DS & ML)
# Out:
# booking_id              0
# property_id             1
# booking_date            1
# check_in_date           1
# checkout_date           1
# no_guests               4
# room_category           1
# booking_platform        1
# ratings_given        6695
# booking_status          1
# revenue_generated       1
# revenue_realized        1
# dtype: int64

# %%
df_bookings.describe() # describe function will give us statictical distribution about the dataset
# Out:
#         property_id     no_guests  ratings_given  revenue_generated  \
# count  11491.000000  11488.000000    4797.000000       1.149100e+04
# mean   17999.889914      2.028552       3.658537       1.944373e+04
# std     1110.247385      1.024495       1.235988       3.037232e+05
# min    16558.000000     -3.000000       1.000000       6.500000e+03
# 25%    16563.000000      1.000000       3.000000       9.900000e+03
# 50%    17564.000000      2.000000       4.000000       1.350000e+04
# 75%    18563.000000      2.000000       5.000000       1.800000e+04
# max    19563.000000      6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count      11491.000000
# mean       12623.126099
# std         6883.241393
# min         2600.000000
# 25%         7600.000000
# 50%        11400.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max() # this show us max & min value for a particular column that we need
# Out:
# (6500.0, 28560000.0)

# %%
df_bookings.room_category.unique() # this  function will give us unique value of particular column
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4', nan], dtype=object)

# %%
df_bookings.booking_platform.value_counts() # this function will give value stored in column
# Out:
# others            4732
# makeyourtrip      2299
# logtrip           1275
# direct online     1092
# tripster           820
# journey            701
# direct offline     572
# Name: booking_platform, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="barh") # here we can counts in bar chart format
# Out:
# <Axes: >

# %%
df_date = pd.read_csv('dim_date.csv')
df_hotels = pd.read_csv('dim_hotels.csv')
df_rooms = pd.read_csv('dim_rooms.csv')
df_agg_bookings = pd.read_csv('fact_aggregated_bookings.csv') #here we add our all remaing dataset & let's explore these data set

# %%
df_hotels.shape #exploring the shape of hotels file
# Out:
# (25, 4)

# %%
df_hotels.head(10) # explore few rows & head function will give top rows
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi
# 5        16563   Atliq Palace  Business   Delhi
# 6        17558   Atliq Grands    Luxury  Mumbai
# 7        17559  Atliq Exotica    Luxury  Mumbai
# 8        17560     Atliq City  Business  Mumbai
# 9        17561      Atliq Blu    Luxury  Mumbai

# %%
df_hotels.city.value_counts() #exploring the value in particular column
# Out:
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: city, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# #Data Cleaning

# %%
df_bookings[df_bookings.no_guests<=0] #here we can check - values in no_of_guests column
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11      16558.0     27-04-22      1/5/2022      2/5/2022
# 3  May012216558RT14      16558.0     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0            10010.0           10010.0
# 3             9100.0            3640.0

# %% [markdown]
# **(1) Clean invalid guests**

# %%
df_bookings = df_bookings[df_bookings.no_guests>0] # here we reverse the so that we can get in positive values
df_bookings.shape
# Out:
# (11486, 12)

# %% [markdown]
# **(2) Outlier removal in revenue generated**

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (6500.0, 28560000.0)

# %%
df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.median()
# Out:
# (19446.358610482326, 13500.0)

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# 930814.1340478883

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -891921.4168269237

# %%
df_bookings[df_bookings.revenue_generated<=0] #removing outliers in revenue genrated column
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#             booking_id  property_id booking_date check_in_date checkout_date  \
# 2     May012216558RT13      16558.0     28-04-22      1/5/2022      4/5/2022
# 111   May012216559RT32      16559.0     29-04-22      1/5/2022      2/5/2022
# 315   May012216562RT22      16562.0     28-04-22      1/5/2022      4/5/2022
# 562  May012217559RT118      17559.0     26-04-22      1/5/2022      2/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 2          2.0           RT1          logtrip            5.0    Checked Out
# 111        6.0           RT3    direct online            NaN    Checked Out
# 315        2.0           RT2   direct offline            3.0    Checked Out
# 562        2.0           RT1           others            NaN      Cancelled
#
#      revenue_generated  revenue_realized
# 2            9100000.0            9100.0
# 111         28560000.0           28560.0
# 315         12600000.0           12600.0
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<=higher_limit]
df_bookings.shape
# Out:
# (11482, 12)

# %%
df_bookings.revenue_realized.describe() #let's do data analysis revenue_realized column bu using statistical meethod
# Out:
# count    11482.000000
# mean     12622.899495
# std       6882.946850
# min       2600.000000
# 25%       7600.000000
# 50%      11400.000000
# 75%      15300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33271.74004456424

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#               booking_id  property_id booking_date check_in_date  \
# 137     May012216559RT41      16559.0     27-04-22      1/5/2022
# 139     May012216559RT43      16559.0     1/5/2022      1/5/2022
# 143     May012216559RT47      16559.0     28-04-22      1/5/2022
# 149    May012216559RT413      16559.0     24-04-22      1/5/2022
# 222     May012216560RT45      16560.0     30-04-22      1/5/2022
# ...                  ...          ...          ...           ...
# 11121  May082216559RT411      16559.0     17-04-22      8/5/2022
# 11123  May082216559RT413      16559.0     1/5/2022      8/5/2022
# 11194   May082216560RT41      16560.0     7/5/2022      8/5/2022
# 11330   May082216562RT41      16562.0     5/5/2022      8/5/2022
# 11432   May082216563RT48      16563.0     8/5/2022      8/5/2022
#
#       checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137        7/5/2022        4.0           RT4           others            NaN
# ...

# %% [markdown]
# One observation we can have in above dataframe is that all rooms are RT4 which means presidential suit. Now since RT4 is a luxurious room it is likely their rent will be higher. To make a fair analysis, we need to do data analysis only on RT4 room types

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count     1363.000000
# mean     23353.300073
# std       9054.673816
# min       7600.000000
# 25%      15960.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
# mean + 3*standard deviation
23439+3*9048
# Out:
# 50583

# %% [markdown]
# Here higher limit comes to be 50583 and in our dataframe above we can see that max value for revenue realized is 45220. Hence we can conclude that there is no outlier and we don't need to do any data cleaning on this particular column

# %%
df_bookings[df_bookings.booking_id=="May012216558RT213"]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings.isnull().sum()
# Out:
# booking_id              0
# property_id             0
# booking_date            0
# check_in_date           0
# checkout_date           0
# no_guests               0
# room_category           0
# booking_platform        0
# ratings_given        6689
# booking_status          0
# revenue_generated       0
# revenue_realized        0
# dtype: int64

# %% [markdown]
# Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, we should not filter these values. Also we should not replace this rating with a median or mean rating etc

# %% [markdown]
# ***
# ### ==> 3. Data Transformation
# Data Transformation is your creating new column you are aggregating data. there could be variety of data transformation

# %% [markdown]
# **Create occupancy percentage column**

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings["occ_pct"].apply(lambda x : round(x*100,2))
df_agg_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# ***
# ### ==> 4. Insights Generation
# ***

# %% [markdown]
# **1. What is an average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2) #here we can get average occupancy rate in each of room category
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %% [markdown]
# I don't understand RT1, RT2 etc. Print room categories such as Standard, Premium, Elite etc along with average occupancy percentage so here we are doing merege with df_rooms to get room_class

# %%
df = pd.merge(df_agg_bookings, df_rooms, left_on="room_category", right_on="room_id")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard

# %%
df.drop("room_id",axis=1, inplace=True) #here we are droping the room_id column
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %% [markdown]
# **2. Print average occupancy rate per city**

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df = pd.merge(df, df_hotels, on="property_id") #here again we are merging using property id
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
#
#    occ_pct room_class property_name_x category_x  city_x property_name_y  \
# 0    83.33   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 1    66.67   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2    56.67   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#   category_y  city_y  property_name category    city
# 0     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 1     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 2     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby("city")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **3. When was the occupancy better? Weekday or Weekend?**

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
#
#    occ_pct room_class property_name_x category_x  city_x  ... category  \
# 0    60.00   Standard   Atliq Exotica     Luxury  Mumbai  ...   Luxury
# 1    60.98      Elite   Atliq Exotica     Luxury  Mumbai  ...   Luxury
# 2    62.50    Premium   Atliq Exotica     Luxury  Mumbai  ...   Luxury
#
#      city     date_x mmm yy_x week no_x day_type_x     date_y mmm yy_y  \
# 0  Mumbai  10-May-22   May 22      W 20   weekeday  10-May-22   May 22
# 1  Mumbai  10-May-22   May 22      W 20   weekeday  10-May-22   May 22
# 2  Mumbai  10-May-22   May 22      W 20   weekeday  10-May-22   May 22
#
#   week no_y day_type_y
# 0      W 20   weekeday
# 1      W 20   weekeday
# ...

# %%
df = pd.merge(df, df_date, left_on="check_in_date", right_on="date") #here we are again merging to get day_type
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
#
#    occ_pct room_class property_name_x category_x  city_x  ... week no_x  \
# 0    60.00   Standard   Atliq Exotica     Luxury  Mumbai  ...      W 20
# 1    60.98      Elite   Atliq Exotica     Luxury  Mumbai  ...      W 20
# 2    62.50    Premium   Atliq Exotica     Luxury  Mumbai  ...      W 20
#
#   day_type_x     date_y mmm yy_y week no_y day_type_y       date  mmm yy  \
# 0   weekeday  10-May-22   May 22      W 20   weekeday  10-May-22  May 22
# 1   weekeday  10-May-22   May 22      W 20   weekeday  10-May-22  May 22
# 2   weekeday  10-May-22   May 22      W 20   weekeday  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# ...

# %%
df.groupby("day_type")["occ_pct"].mean().round(2) #checking when is the occupancy rate is better
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %% [markdown]
# **4: In the month of June, what is the occupancy for different cities**

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22 = df[df["mmm yy"]=="Jun 22"] #here we are filtering data on june column
df_june_22.head(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
# 2203        16559     10-Jun-22           RT4                   11      18.0
#
#       occ_pct    room_class property_name_x category_x  city_x  ... week no_x  \
# 2200    66.67      Standard   Atliq Exotica     Luxury  Mumbai  ...      W 24
# 2201    63.41         Elite   Atliq Exotica     Luxury  Mumbai  ...      W 24
# 2202    62.50       Premium   Atliq Exotica     Luxury  Mumbai  ...      W 24
# 2203    61.11  Presidential   Atliq Exotica     Luxury  Mumbai  ...      W 24
#
#      day_type_x     date_y mmm yy_y week no_y day_type_y       date  mmm yy  \
# 2200   weekeday  10-Jun-22   Jun 22      W 24   weekeday  10-Jun-22  Jun 22
# ...

# %%
df_june_22.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending=False) # grouping june data basis of cities
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %% [markdown]
# so here we get to know that dehli is performing well in june month & in banglore occupacny rate is lowest

# %%
df_june_22.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **5: We got new data for the month of august. Append that to existing data**

# %%
df_august = pd.read_csv("new_data_august.csv")
df_august.head(5)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.columns #checking the number of columns are same or not with new dataset
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name_x', 'category_x',
#        'city_x', 'property_name_y', 'category_y', 'city_y', 'property_name',
#        'category', 'city', 'date_x', 'mmm yy_x', 'week no_x', 'day_type_x',
#        'date_y', 'mmm yy_y', 'week no_y', 'day_type_y', 'date', 'mmm yy',
#        'week no', 'day_type'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 28)

# %%
latest_df = pd.concat([df, df_august], ignore_index = True, axis = 0) #here we concat the the two dataframe join them like rows
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class property_name_x category_x     city_x  ...  \
# ...

# %%
latest_df.shape
# Out:
# (6507, 29)

# %% [markdown]
# **6. Print revenue realized per city**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12      16558.0     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15      16558.0     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16      16558.0     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17      16558.0     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18      16558.0     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_bookings_all = pd.merge(df_bookings, df_hotels, on="property_id") #again we are doing to get merege to get revenue
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12      16558.0     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15      16558.0     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16      16558.0     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0             9100.0            3640.0  Atliq Grands   Luxury  Delhi
# 1            10920.0           10920.0  Atliq Grands   Luxury  Delhi
# 2             9100.0            9100.0  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum() # here we get total revenue with per city
# Out:
# city
# Bangalore    34523895.0
# Delhi        28297514.0
# Hyderabad    26694910.0
# Mumbai       55419813.0
# Name: revenue_realized, dtype: float64

# %% [markdown]
# **7. Print month by month revenue**

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12      16558.0     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15      16558.0     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16      16558.0     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0             9100.0            3640.0  Atliq Grands   Luxury  Delhi
# 1            10920.0           10920.0  Atliq Grands   Luxury  Delhi
# 2             9100.0            9100.0  Atliq Grands   Luxury  Delhi

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"] = pd.to_datetime(df_date["date"]) # here we do same format of date
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4801 entries, 0 to 4800
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         4801 non-null   object
#  1   property_id        4801 non-null   float64
#  2   booking_date       4801 non-null   object
#  3   check_in_date      4801 non-null   datetime64[ns]
#  4   checkout_date      4801 non-null   object
#  5   no_guests          4801 non-null   float64
#  6   room_category      4801 non-null   object
#  7   booking_platform   4801 non-null   object
#  8   ratings_given      1973 non-null   float64
#  9   booking_status     4801 non-null   object
#  10  revenue_generated  4801 non-null   float64
#  11  revenue_realized   4801 non-null   float64
#  12  property_name      4801 non-null   object
#  13  category           4801 non-null   object
#  14  city               4801 non-null   object
# ...

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(df_bookings_all["check_in_date"])
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11      16558.0     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12      16558.0     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13      16558.0     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14      16558.0     3/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0            10010.0           10010.0  Atliq Grands   Luxury  Delhi
# 1             9100.0            3640.0  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11      16558.0     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12      16558.0     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13      16558.0     1/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
#
#    ...  week no_x  day_type_x     date_y mmm yy_y week no_y day_type_y  \
# 0  ...       W 19    weekeday 2022-05-05   May 22      W 19   weekeday
# 1  ...       W 19    weekeday 2022-05-05   May 22      W 19   weekeday
# 2  ...       W 19    weekeday 2022-05-05   May 22      W 19   weekeday
#
#         date  mmm yy week no  day_type
# 0 2022-05-05  May 22    W 19  weekeday
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    25221983.0
# Jun 22    17426886.0
# May 22    17901036.0
# Name: revenue_realized, dtype: float64
